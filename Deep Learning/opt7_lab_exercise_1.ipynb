# %%
import re
import numpy as np
import torch
import torch.autograd as ag
import torch.nn.functional as F
import torch.nn as nn
import torch.optim.lr_scheduler as lr_sch
import matplotlib.pyplot as plt
from time import clock

# %% [markdown]
# # Deep Learning for NLP - lab exercise 1
#
# In this first lab exercise we will implement a simple bag-of-word classifier, i.e. a classifier that ignores the sequential structure of the sentence. The goal is to predict if a sentence is a positive or negative review of a movie. We will use a dataset constructed from IMDB.
#
# 1. Load and clean the data
# 2. Preprocess the data for the NN
# 3. Module definition
# 4. Train the network!
#
# We will implement this model with Pytorch, the most popular deep learning framework for Natural Language Processing. You can use the following links for help:
# * turorials: http://pytorch.org/tutorials/
# * documentation: http://pytorch.org/docs/master/
#
# **Hard deadline**: December 3, 2019
#
#
# ## Report
#
# On top of this notebook, you must submit a report explaining your neural network, it's training method and report+analyse results, for example with different hyper-parameters (number of hidden layers, different embedding size, different hidden representation size, w or w/o dropout...you choose what you want to explore!).
# You can also report results with different training dataset sizes (how does the number of training instances impact dev/test results? => *WARNING* obviously, here you change the training set size but you freeze the dev/test sets).
#
# Training with the full dataset may be slow depending on your computer.
#
# ## Data
#
# The data can be download here: http://teaching.caio-corro.fr/2019-2020/OPT7/imdb.zip
#
# There are two files: one with positive reviews (imdb.pos) and one with negative reviews (imdb.neg). Each file contains 300000 reviews, one per line.
#
#
# The following functions can be used to load and clean the data.

# %%
# Tokenize a sentence
def clean_str(string, tolower=True):
    """
    Tokenization/string cleaning.
    Original taken from https://github.com/yoonkim/CNN_sentence/blob/master/process_data.py
    """
    string = re.sub(r"[^A-Za-z0-9(),!?\'\`]", " ", string)
    string = re.sub(r"\'s", " \'s", string)
    string = re.sub(r"\'ve", " \'ve", string)
    string = re.sub(r"n\'t", " n\'t", string)
    string = re.sub(r"\'re", " \'re", string)
    string = re.sub(r"\'d", " \'d", string)
    string = re.sub(r"\'ll", " \'ll", string)
    string = re.sub(r",", " , ", string)
    string = re.sub(r"!", " ! ", string)
    string = re.sub(r"\(", " \( ", string)
    string = re.sub(r"\)", " \) ", string)
    string = re.sub(r"\?", " \? ", string)
    string = re.sub(r"\s{2,}", " ", string)
    if tolower:
        string = string.lower()
    return string.strip()


# reads the content of the file passed as an argument.
# if limit > 0, this function will return only the first "limit" sentences in the file.
def loadTexts(filename, limit=-1):
    f = open(filename)
    dataset=[]
    line =  f.readline()
    cpt=1
    skip=0
    while line :
        cleanline = clean_str(f.readline()).split()
        if cleanline: 
            dataset.append(cleanline)
        else: 
            line = f.readline()
            skip+=1
            continue
        if limit > 0 and cpt >= limit: 
            break
        line = f.readline()
        cpt+=1        
        
    f.close()
    print("Load ", cpt, " lines from ", filename , " / ", skip ," lines discarded")
    return dataset

# %% [markdown]
# The following cell load the first 5000 sentences in each review set.

# %%
LIM=5000
txtfile = "imdb.pos"  # path of the file containing positive reviews
postxt = loadTexts(txtfile,limit=LIM)

txtfile = "imdb.neg"  # path of the file containing negative reviews
negtxt = loadTexts(txtfile,limit=LIM)
# Out:
# Load  5000  lines from  imdb.pos  /  1  lines discarded
# Load  5000  lines from  imdb.neg  /  1  lines discarded

# %% [markdown]
# Split the data between train / dev / test, for example by creating lists txt_train, label_train, txt_dev, ... You should take care to keep a 50/50 ratio between positive and negative instances in each set.

# %%
txt = postxt + negtxt
label = list(np.ones(LIM, int))+list(np.zeros(LIM, int))

# %%
from sklearn.model_selection import train_test_split

txt_train, txt_dev, label_train, label_dev = train_test_split(txt, label, test_size=0.1, random_state=26 ,stratify=label)

txt_train, txt_test, label_train, label_test = train_test_split(txt_train , label_train , test_size=0.1, random_state = 26 , stratify=label_train)

# %% [markdown]
# # Converting data to Pytorch tensors
#
# We will first convert data to Pytorch tensors so they can be used in a neural network.
# To do that, you must first create a dictionnary that will map words to integers.
# Add to the dictionnary only words that are in the training set (be sure to understand why we do that!).
#
# Then, you can convert the data to tensors:
# - use tensors of longs: both the sentence and the label will be represented as integers, not floats!
# - these tensors do not require a gradient
#
# A tensor representing a sentence is composed of the integer representation of each word, e.g. [10, 256, 3, 4].
# Note that some words in the dev and test sets may not be in the dictionnary! (i.e. unknown words)
# You can just skip them.

# %%
class Dict:
    def __init__(self, words, unk=None):
        self._unk = unk
        self._word_to_id = dict()
        self._id_to_word = list()

        if unk in words:
            raise RuntimeError("UNK word exists in vocabulary")

        if unk is not None:
            self.unk_index = self._add_word(unk)

        for word in words:
            self._add_word(word)

    # for internal use only!
    def _add_word(self, word):
        if word not in self._word_to_id:
            id = len(self._id_to_word)
            self._word_to_id[word] = id
            self._id_to_word.append(word)
            return id
        else:
            return self._word_to_id[word]

    def str_to_id(self, word):
        if self._unk is not None:
            return self._word_to_id.get(word, self.unk_index)
        else:
            return self._word_to_id[word]

    def id_to_str(self, id):
        return self._id_to_word[id]

    def __len__(self):
        return len(self._word_to_id)

    def has_unk(self):
        return self._unk is not None
    
    def unk(self):
        return self.unk_index

# %%
#Creating a dictionary where each word is associated to an index
word_index = {}
for sentence in txt_train:
    for word in sentence:
        if word not in word_index:
            word_index[word] = len(word_index) + 1

# %%
Dict_train_ = Dict(word_index, unk=True)

# %% [markdown]
# # Neural network definition
#
# The neural network should be defined as follows:
# - it takes as input a tensor that is a sequence of integers indexing word embeddings
# - it retrieves the word embeddings from an embedding table
# - it constructs the "input" of the MLP by summing over all embeddings (i.e. bag-of-word model)
# - it build a hidden represention using a MLP (1 layer? 2 layers? experiment! but maybe first try wihout any hidden layer...)
# - it project the hidden representation to the output space: it is a binary classification task, so the output space is a scalar where a negative (resp. positive) value means the review is negative (resp. positive).

# %%
class CBOW_classifier(nn.Module):
    def __init__(self, vocab_size, embedding_dim):
        super(CBOW_classifier, self).__init__()
        
        """
       A text classifier: 
       - input = a list of word indices 
       - output = probability associated to a binary classification task
       The pooling operation is the sum

       To build it, two args : 
       - vocab_size: the number of words in the vocabulary we want to embed
       - embedding_dim: size of the word vectors
        """
        # To create an embedding table: https://pytorch.org/docs/stable/nn.html#torch.nn.Embedding
        self.embeddings = nn.Embedding(num_embeddings = vocab_size, embedding_dim=embedding_dim)
        self.linear1 = nn.Linear(embedding_dim, 1)
        
        # Parameter initialization
        nn.init.xavier_uniform_(self.linear1.weight.data)
        nn.init.zeros_(self.linear1.bias.data)
        
        #self.out = nn.Sigmoid() # because we'll use BCELoass : binary cross entropy
        
    def forward(self, inputs):
        # TODO
            inp = self.embeddings(inputs).sum(dim=0)
            return self.linear1(inp)

# %% [markdown]
# ## Loss function
#
# Create a loss function builder.
#
# - Pytorch loss functions are documented here: https://pytorch.org/docs/stable/nn.html#loss-functions
# - In our case, we are interested in *BCELoss* and *BCEWithLogitsLoss*. Read their documentation and choose the one that fits with your network output

# %%
loss = nn.BCEWithLogitsLoss()

# %% [markdown]
# ## Training loop
#
# Write your training loop!
#
# - parameterizable number of epochs
# - at each epoch, print the mean loss and the dev accuracy

# %%
def train(model , epochs, X_train ,y_train , X_dev , y_dev , optimizer):   
        
    #variables to see the progression
    mean_loss_train = []
    mean_loss_dev = []
    acc_train = []
    acc_dev = []
    
    
    #passe le modele en mode training
    model.train()
    
    for i in range(epochs):
        #defining parameters to print the evolution of the NN
        accuracy = 0
        mean_loss = 0
        
        #shuffle to reduce overfitting
        d = list(zip(X_train, y_train))
        np.random.shuffle(d)
        X_train, y_train = zip(*d)
        
        for sentence,label in zip(X_train , y_train):
            
            # initialize the parameters gradient to zero
            optimizer.zero_grad()
            
            #Creating the tensors for inputs
            data = torch.LongTensor([Dict_train_.str_to_id(word) for word in sentence])
            label = torch.Tensor([label])
            #prediction and loss
            pred = model(data)
            loss_out = loss(pred , label)
            mean_loss+=loss_out.item()
            
            #Backward and updates
            loss_out.backward()
            optimizer.step()

            #Computing accuracy
        if (prediction >= 0.5 and label==1) or (prediction<0.5 and label==0):
                accuracy += 1
            
        mean_loss_train.append(mean_loss/len(X_train))
        accuracy_train.append(accuracy/len(X_train))
        
        print("EPOCH" , str(i+1) ,"On the training data : mean loss is :" , mean_loss/len(X_train) , "accuracy is: " ,accuracy/len(X_train))


        mean_loss = 0
        accuracy = 0
        
        #testing on dev data
        for sentence,label in zip(X_dev,y_dev):
            data = torch.LongTensor([Dict_train_.str_to_id(word) for word in sentence])
            label = torch.Tensor([label])
            
            #prediction and loss
            prediction = model(data)
            loss_out = loss(prediction , label)
            
            mean_loss+=loss_out.item()
            
            
            #computing accuracy
            if (prediction >= 0.5 and label==1) or (prediction < 0.5 and label==0):
                accuracy += 1
            
        print("EPOCH" , str(i+1) ,"On the dev data : mean loss is : " , mean_loss/len(X_dev) , " accuracy is : " ,accuracy/len(X_dev))
        print("----------------------------------------------------------------------------")
        mean_loss_dev.append(mean_loss/len(X_dev))
        acc_dev.append(accuracy/len(X_dev))
          
            
            
    #Plotting accuracy curves for dev and train data
    plt.figure()
    plt.plot(accuracy_train , label='Train')
    plt.plot(acc_dev, label="Dev")
    plt.title("Accuracy in term of epochs")
    plt.xlabel("Epochs")
    plt.ylabel("Accuracy")
    plt.legend()
    
    #Plotting loss curves for dev and train data
    plt.figure()    
    plt.plot(mean_loss_train , label='Train')
    plt.plot(mean_loss_dev, label="Dev")
    plt.title("Loss in term of epochs")
    plt.xlabel("Epochs")
    plt.ylabel("Loss")
    plt.legend()

# %%
#Calculating accuracy on test data
def test_accuracy(model,  X_test , y_test):
    
    accuracy = 0
    mean_loss = 0
        
    for sentence,label in zip(X_test,y_test):
        data = torch.LongTensor([Dict_train_.str_to_id(word) for word in sentence])
        label = torch.Tensor([label])
             
        prediction = model(data)
        loss_out = loss(prediction , label)
        mean_loss += loss_out.item()
                        
            
        #computing accuracy
        if (prediction >= 0.5 and label==1) or (prediction<0.5 and label==0):
            accuracy += 1

            
    print("Accuracy on test set for this model is" , accuracy/len(X_test))
    return(accuracy/len(X_test))

# %%
embedding_dim = 50
model_1 = CBOW_classifier (len(Dict_train_)+1, embedding_dim)
lr = 0.1
n_epochs = 10
optimizer = torch.optim.SGD(params=model_1.parameters(), lr=lr, weight_decay=1e-3)
train(model_1, n_epochs, txt_train ,label_train, txt_dev, label_dev, optimizer)
# Out:
# EPOCH 1 The mean loss in training data : 3.1948911305584247 Accuracy is :  0.6161728395061729
# EPOCH 1 The mean loss in dev data  1.1989585479625293 Accuracy is :  0.658
# ----------------------------------------------------------------
# EPOCH 2 The mean loss in training data : 0.6972672939888334 Accuracy is :  0.7180246913580247
# EPOCH 2 The mean loss in dev data  0.6171848155984226 Accuracy is :  0.726
# ----------------------------------------------------------------
# EPOCH 3 The mean loss in training data : 0.492425448965954 Accuracy is :  0.7693827160493827
# EPOCH 3 The mean loss in dev data  0.5707604250350996 Accuracy is :  0.724
# ----------------------------------------------------------------
# EPOCH 4 The mean loss in training data : 0.4633806975490103 Accuracy is :  0.7753086419753087
# EPOCH 4 The mean loss in dev data  0.5118212757791243 Accuracy is :  0.73
# ----------------------------------------------------------------
# EPOCH 5 The mean loss in training data : 0.4594847475090246 Accuracy is :  0.7803703703703704
# EPOCH 5 The mean loss in dev data  0.5207663358985738 Accuracy is :  0.713
# ----------------------------------------------------------------
# EPOCH 6 The mean loss in training data : 0.4583818636267578 Accuracy is :  0.7774074074074074
# EPOCH 6 The mean loss in dev data  0.4998486145273782 Accuracy is :  0.753
# ----------------------------------------------------------------
# EPOCH 7 The mean loss in training data : 0.45210370821628487 Accuracy is :  0.7828395061728395
# EPOCH 7 The mean loss in dev data  0.508284634431824 Accuracy is :  0.736
# ----------------------------------------------------------------
# EPOCH 8 The mean loss in training data : 0.44862130491187724 Accuracy is :  0.7860493827160494
# EPOCH 8 The mean loss in dev data  0.508830625792325 Accuracy is :  0.736
# ----------------------------------------------------------------
# EPOCH 9 The mean loss in training data : 0.4582981104968724 Accuracy is :  0.7881481481481482
# EPOCH 9 The mean loss in dev data  0.5027216635833757 Accuracy is :  0.719
# ----------------------------------------------------------------
# EPOCH 10 The mean loss in training data : 0.4560450098413755 Accuracy is :  0.7824691358024691
# EPOCH 10 The mean loss in dev data  0.5119979649045563 Accuracy is :  0.743
# ----------------------------------------------------------------

# %%
test_accuracy(model_1,  txt_test , label_test)
# Out:
# Accuracy on test set for this model is 0.7411111111111112

# %% [markdown]
# ### Remarks :
# 1) The curve of the accuracy on the training data is globaly increasing in terms of epochs but it is fluctuente. To solve this problem we need to decrease the learning rate. Or decreasing this one is time consuming. Then adaptative learning optimizer seems a good solution to use. We will try then to training our model using the adaptative learning optimizer "Adam" and "AdaDelta".
#
# 2) The curve of the accuracy on the validation data is globaly increasing in terms of epochs but it is fluctuente. This fluctuency is due to the overfitting of the model. To avoid this problem. We can try possible solutions like below :
#
# * obtain more data-points (or artificially expand the set of existing ones).
# * play with hyper-parameters (embedding size, number of hidden layers).
# * regularization: try dropout, early-stopping, so on.
#
# Getting more training data is a good way to avoid overfitting whereas this solution is time consuming. For that reasons we will only try the two other solutions.

# %%
embedding_dim = 50
model = CBOW_classifier(len(Dict_train_)+1, embedding_dim)
models = [model, model, model]
optimizers = [ 
    torch.optim.SGD(params=models[0].parameters(), lr=0.01, weight_decay=1e-4),
    torch.optim.Adadelta(params=models[1].parameters(), lr=1.0, rho=0.9, eps=1e-06),
    torch.optim.Adam(params=models[2].parameters())
]

accuracy = []
n_epochs = [4, 4, 4] # found these values doing preliminary tests
i = 0
for optimizer, n_epochs in zip(optimizers, n_epochs):
    print("Optimizer : ", i+1)
    start_time = clock()
    train(models[i], n_epochs, txt_train ,label_train, txt_dev, label_dev, optimizer) 
    print("Duration is ", clock() - start_time)
    accuracy.append(test_accuracy(models[i],  txt_test , label_test))
    i += 1
# Out:
# Optimizer :  1
# EPOCH 1 On the training data : mean loss is : 1.0348448490874484 accuracy is:  0.5593827160493827
# EPOCH 1 On the dev data : mean loss is :  1.0354150922811314  accuracy is :  0.589
# ----------------------------------------------------------------------------
# EPOCH 2 On the training data : mean loss is : 0.9819201586004647 accuracy is:  0.5787654320987654
# EPOCH 2 On the dev data : mean loss is :  0.9814877727784733  accuracy is :  0.565
# ----------------------------------------------------------------------------
# EPOCH 3 On the training data : mean loss is : 0.9312021928544174 accuracy is:  0.5932098765432099
# EPOCH 3 On the dev data : mean loss is :  0.8983026612653358  accuracy is :  0.574
# ----------------------------------------------------------------------------
# EPOCH 4 On the training data : mean loss is : 0.8857175955560277 accuracy is:  0.6155555555555555
# EPOCH 4 On the dev data : mean loss is :  0.88213334404114  accuracy is :  0.588
# ----------------------------------------------------------------------------
# Duration is  95.60484410000004
# Accuracy on test set for this model is 0.5888888888888889
# Optimizer :  2
# EPOCH 1 On the training data : mean loss is : 0.6228224241060656 accuracy is:  0.6854320987654321
# EPOCH 1 On the dev data : mean loss is :  0.5837923205122352  accuracy is :  0.689
# ----------------------------------------------------------------------------
# EPOCH 2 On the training data : mean loss is : 0.5629210127661911 accuracy is:  0.7232098765432099
# EPOCH 2 On the dev data : mean loss is :  0.5495362628038784  accuracy is :  0.729
# ----------------------------------------------------------------------------
# EPOCH 3 On the training data : mean loss is : 0.5399893449906497 accuracy is:  0.7417283950617284
# EPOCH 3 On the dev data : mean loss is :  0.5473816236205458  accuracy is :  0.733
# ----------------------------------------------------------------------------
# EPOCH 4 On the training data : mean loss is : 0.5236980113939091 accuracy is:  0.7534567901234568
# EPOCH 4 On the dev data : mean loss is :  0.553838512300404  accuracy is :  0.733
# ----------------------------------------------------------------------------
# Duration is  320.67092319999983
# Accuracy on test set for this model is 0.7355555555555555
# Optimizer :  3
# EPOCH 1 On the training data : mean loss is : 0.4695349971652655 accuracy is:  0.7645679012345679
# EPOCH 1 On the dev data : mean loss is :  0.4706205818351591  accuracy is :  0.772
# ----------------------------------------------------------------------------
# EPOCH 2 On the training data : mean loss is : 0.39184004543375645 accuracy is:  0.815679012345679
# EPOCH 2 On the dev data : mean loss is :  0.4818553066300434  accuracy is :  0.778
# ----------------------------------------------------------------------------
# EPOCH 3 On the training data : mean loss is : 0.3369775625278334 accuracy is:  0.8491358024691358
# EPOCH 3 On the dev data : mean loss is :  0.49112800103358156  accuracy is :  0.791
# ----------------------------------------------------------------------------
# EPOCH 4 On the training data : mean loss is : 0.2956546828398847 accuracy is:  0.8718518518518519
# EPOCH 4 On the dev data : mean loss is :  0.49715343096460907  accuracy is :  0.79
# ----------------------------------------------------------------------------
# Duration is  311.1949010000001
# Accuracy on test set for this model is 0.7733333333333333

# %%
plt.figure(figsize=(6, 3))
plt.title("Effect of the optimizer on the test accuracy")
optimizer = ('SGD with high lr', 'SGD with low lr', 'Adadelta', 'Adam')
optimizer_index = np.arange(len(optimizer))

acc = [0.741] + accuracy # we already tried with SGD with high lr where we obtained accuracy = 0.741
plt.bar(optimizer_index, acc, align='center', alpha=0.5)
plt.xticks(optimizer_index, optimizer)
plt.ylabel('Accuracy')
# Out:
# Text(0,0.5,'Accuracy')

# %%
plt.figure(figsize=(6, 3))
plt.title("Effect of the optimizer on the training duration")
optimizer = ('SGD with low lr', 'Adadelta', 'Adam')
optimizer_index = np.arange(len(optimizer))

times = [95.60, 320.67092319999983, 311.1949010000001]
plt.bar(optimizer_index, times, align='center', alpha=0.5)
plt.xticks(optimizer_index, optimizer)
plt.ylabel('times')
# Out:
# Text(0,0.5,'times')

# %% [markdown]
# ### Hyperparameter : embedding size

# %%
accuracy = []
durations = []
dimensions = [1, 10, 20, 30, 60]
for embedding_dim in dimensions:
    model = CBOW_classifier(len(Dict_train_)+1, embedding_dim)
    n_epochs = 10
    optimizer = torch.optim.Adam(params=model.parameters()) 
    start_time = clock()
    train(model, n_epochs, txt_train, label_train, txt_dev, label_dev, optimizer)
    print("Duration is ", clock() - start_time)
    accuracy.append(test_accuracy(model, txt_test, label_test))
# Out:
# EPOCH 1 On the training data : mean loss is : 0.7480287811536542 accuracy is:  0.5135802469135803
# EPOCH 1 On the dev data : mean loss is :  0.6797653437703848  accuracy is :  0.527
# ----------------------------------------------------------------------------
# EPOCH 2 On the training data : mean loss is : 0.6494684129877499 accuracy is:  0.5803703703703704
# EPOCH 2 On the dev data : mean loss is :  0.6463814936690032  accuracy is :  0.604
# ----------------------------------------------------------------------------
# EPOCH 3 On the training data : mean loss is : 0.5922598872588442 accuracy is:  0.6565432098765432
# EPOCH 3 On the dev data : mean loss is :  0.6198032277664169  accuracy is :  0.662
# ----------------------------------------------------------------------------
# EPOCH 4 On the training data : mean loss is : 0.5438898266791466 accuracy is:  0.7090123456790124
# EPOCH 4 On the dev data : mean loss is :  0.5921140329703921  accuracy is :  0.686
# ----------------------------------------------------------------------------
# EPOCH 5 On the training data : mean loss is : 0.5046802859894908 accuracy is:  0.7414814814814815
# EPOCH 5 On the dev data : mean loss is :  0.5636870440893108  accuracy is :  0.702
# ----------------------------------------------------------------------------
# EPOCH 6 On the training data : mean loss is : 0.4728966361040073 accuracy is:  0.7619753086419753
# EPOCH 6 On the dev data : mean loss is :  0.5652315577079098  accuracy is :  0.712
# ----------------------------------------------------------------------------
# EPOCH 7 On the training data : mean loss is : 0.44658139979187594 accuracy is:  0.7779012345679013
# EPOCH 7 On the dev data : mean loss is :  0.5578652621981782  accuracy is :  0.732
# ----------------------------------------------------------------------------
# EPOCH 8 On the training data : mean loss is : 0.4246476374311402 accuracy is:  0.7916049382716049
# EPOCH 8 On the dev data : mean loss is :  0.5495387406941199  accuracy is :  0.739
# ----------------------------------------------------------------------------
# EPOCH 9 On the training data : mean loss is : 0.4054716472581245 accuracy is:  0.8033333333333333
# EPOCH 9 On the dev data : mean loss is :  0.5444315855073748  accuracy is :  0.749
# ----------------------------------------------------------------------------
# EPOCH 10 On the training data : mean loss is : 0.38860305887375346 accuracy is:  0.812962962962963
# EPOCH 10 On the dev data : mean loss is :  0.5483854082303438  accuracy is :  0.751
# ----------------------------------------------------------------------------
# Duration is  85.89051449999988
# Accuracy on test set for this model is 0.75
# EPOCH 1 On the training data : mean loss is : 0.7867064728778326 accuracy is:  0.5904938271604938
# EPOCH 1 On the dev data : mean loss is :  0.5848997976854443  accuracy is :  0.653
# ----------------------------------------------------------------------------
# EPOCH 2 On the training data : mean loss is : 0.5220457981072014 accuracy is:  0.7254320987654321
# EPOCH 2 On the dev data : mean loss is :  0.5148452904772712  accuracy is :  0.719
# ----------------------------------------------------------------------------
# EPOCH 3 On the training data : mean loss is : 0.43462245424543045 accuracy is:  0.7875308641975308
# EPOCH 3 On the dev data : mean loss is :  0.49456875137702627  accuracy is :  0.743
# ----------------------------------------------------------------------------
# EPOCH 4 On the training data : mean loss is : 0.3835477649423416 accuracy is:  0.8204938271604938
# EPOCH 4 On the dev data : mean loss is :  0.48878159133537213  accuracy is :  0.762
# ----------------------------------------------------------------------------
# EPOCH 5 On the training data : mean loss is : 0.3466152616903594 accuracy is:  0.8434567901234568
# EPOCH 5 On the dev data : mean loss is :  0.4948339376425552  accuracy is :  0.761
# ----------------------------------------------------------------------------
# EPOCH 6 On the training data : mean loss is : 0.3170471954868572 accuracy is:  0.8597530864197531
# EPOCH 6 On the dev data : mean loss is :  0.5028020750492337  accuracy is :  0.766
# ----------------------------------------------------------------------------
# EPOCH 7 On the training data : mean loss is : 0.2930855020208182 accuracy is:  0.8728395061728395
# EPOCH 7 On the dev data : mean loss is :  0.5163862654042218  accuracy is :  0.766
# ----------------------------------------------------------------------------
# EPOCH 8 On the training data : mean loss is : 0.2730425620606525 accuracy is:  0.8839506172839506
# EPOCH 8 On the dev data : mean loss is :  0.5367318414710806  accuracy is :  0.765
# ----------------------------------------------------------------------------
# EPOCH 9 On the training data : mean loss is : 0.25523906739991076 accuracy is:  0.8919753086419753
# EPOCH 9 On the dev data : mean loss is :  0.5531611985877462  accuracy is :  0.762
# ----------------------------------------------------------------------------
# EPOCH 10 On the training data : mean loss is : 0.23968473101340662 accuracy is:  0.8983950617283951
# EPOCH 10 On the dev data : mean loss is :  0.5616801574036882  accuracy is :  0.773
# ----------------------------------------------------------------------------
# Duration is  187.4329472000004
# Accuracy on test set for this model is 0.7488888888888889
# EPOCH 1 On the training data : mean loss is : 0.7603411899176165 accuracy is:  0.5966666666666667
# EPOCH 1 On the dev data : mean loss is :  0.5842440387504175  accuracy is :  0.66
# ----------------------------------------------------------------------------
# EPOCH 2 On the training data : mean loss is : 0.4862007740831113 accuracy is:  0.7540740740740741
# EPOCH 2 On the dev data : mean loss is :  0.486324289171258  accuracy is :  0.751
# ----------------------------------------------------------------------------
# EPOCH 3 On the training data : mean loss is : 0.39736375520082334 accuracy is:  0.8107407407407408
# EPOCH 3 On the dev data : mean loss is :  0.4855145404445229  accuracy is :  0.747
# ----------------------------------------------------------------------------
# EPOCH 4 On the training data : mean loss is : 0.34284370877286513 accuracy is:  0.8437037037037037
# EPOCH 4 On the dev data : mean loss is :  0.510671462874944  accuracy is :  0.748
# ----------------------------------------------------------------------------
# EPOCH 5 On the training data : mean loss is : 0.3052665021712335 accuracy is:  0.867037037037037
# EPOCH 5 On the dev data : mean loss is :  0.5394188134917852  accuracy is :  0.76
# ----------------------------------------------------------------------------
# EPOCH 6 On the training data : mean loss is : 0.2739412061288076 accuracy is:  0.8802469135802469
# EPOCH 6 On the dev data : mean loss is :  0.5531829062792895  accuracy is :  0.762
# ----------------------------------------------------------------------------
# EPOCH 7 On the training data : mean loss is : 0.2504123481558397 accuracy is:  0.892962962962963
# EPOCH 7 On the dev data : mean loss is :  0.5565033033304401  accuracy is :  0.764
# ----------------------------------------------------------------------------
# EPOCH 8 On the training data : mean loss is : 0.2307198409551967 accuracy is:  0.9011111111111111
# EPOCH 8 On the dev data : mean loss is :  0.5788540964761194  accuracy is :  0.771
# ----------------------------------------------------------------------------
# EPOCH 9 On the training data : mean loss is : 0.2133197661726311 accuracy is:  0.9124691358024691
# EPOCH 9 On the dev data : mean loss is :  0.5934646356656327  accuracy is :  0.771
# ----------------------------------------------------------------------------
# EPOCH 10 On the training data : mean loss is : 0.19941091441908612 accuracy is:  0.918395061728395
# EPOCH 10 On the dev data : mean loss is :  0.6391616148948635  accuracy is :  0.768
# ----------------------------------------------------------------------------
# Duration is  322.5501653000001
# Accuracy on test set for this model is 0.7588888888888888
# EPOCH 1 On the training data : mean loss is : 0.7565977323483949 accuracy is:  0.6365432098765432
# EPOCH 1 On the dev data : mean loss is :  0.5640756695801392  accuracy is :  0.693
# ----------------------------------------------------------------------------
# EPOCH 2 On the training data : mean loss is : 0.465680752244096 accuracy is:  0.7696296296296297
# EPOCH 2 On the dev data : mean loss is :  0.5158682527687851  accuracy is :  0.754
# ----------------------------------------------------------------------------
# EPOCH 3 On the training data : mean loss is : 0.38105415380420954 accuracy is:  0.8240740740740741
# EPOCH 3 On the dev data : mean loss is :  0.5234183347564977  accuracy is :  0.757
# ----------------------------------------------------------------------------
# EPOCH 4 On the training data : mean loss is : 0.3272361259247308 accuracy is:  0.8535802469135803
# EPOCH 4 On the dev data : mean loss is :  0.5405035022144211  accuracy is :  0.76
# ----------------------------------------------------------------------------
# EPOCH 5 On the training data : mean loss is : 0.2894035825062039 accuracy is:  0.8748148148148148
# EPOCH 5 On the dev data : mean loss is :  0.5449423652505097  accuracy is :  0.77
# ----------------------------------------------------------------------------
# EPOCH 6 On the training data : mean loss is : 0.2608539142019872 accuracy is:  0.885679012345679
# EPOCH 6 On the dev data : mean loss is :  0.5670455351861123  accuracy is :  0.763
# ----------------------------------------------------------------------------
# EPOCH 7 On the training data : mean loss is : 0.23769127802073836 accuracy is:  0.9014814814814814
# EPOCH 7 On the dev data : mean loss is :  0.6294046297813113  accuracy is :  0.766
# ----------------------------------------------------------------------------
# EPOCH 8 On the training data : mean loss is : 0.21923340429065846 accuracy is:  0.9124691358024691
# EPOCH 8 On the dev data : mean loss is :  0.6391109618279047  accuracy is :  0.765
# ----------------------------------------------------------------------------
# EPOCH 9 On the training data : mean loss is : 0.20418952030943294 accuracy is:  0.9181481481481482
# EPOCH 9 On the dev data : mean loss is :  0.671717326904621  accuracy is :  0.767
# ----------------------------------------------------------------------------
# EPOCH 10 On the training data : mean loss is : 0.19007531031726738 accuracy is:  0.9214814814814815
# EPOCH 10 On the dev data : mean loss is :  0.6791273692910696  accuracy is :  0.767
# ----------------------------------------------------------------------------
# Duration is  473.0279228999998
# Accuracy on test set for this model is 0.7522222222222222
# EPOCH 1 On the training data : mean loss is : 0.7181193672791298 accuracy is:  0.6428395061728395
# EPOCH 1 On the dev data : mean loss is :  0.5445667428369634  accuracy is :  0.735
# ----------------------------------------------------------------------------
# EPOCH 2 On the training data : mean loss is : 0.4520160378727697 accuracy is:  0.7788888888888889
# EPOCH 2 On the dev data : mean loss is :  0.48860112636826486  accuracy is :  0.765
# ----------------------------------------------------------------------------
# EPOCH 3 On the training data : mean loss is : 0.36397612769392024 accuracy is:  0.8345679012345679
# EPOCH 3 On the dev data : mean loss is :  0.49008597136139564  accuracy is :  0.782
# ----------------------------------------------------------------------------
# EPOCH 4 On the training data : mean loss is : 0.311105879454412 accuracy is:  0.8604938271604938
# EPOCH 4 On the dev data : mean loss is :  0.5106928143337951  accuracy is :  0.78
# ----------------------------------------------------------------------------
# EPOCH 5 On the training data : mean loss is : 0.27266507947518803 accuracy is:  0.8859259259259259
# EPOCH 5 On the dev data : mean loss is :  0.5376077021583804  accuracy is :  0.776
# ----------------------------------------------------------------------------
# EPOCH 6 On the training data : mean loss is : 0.24257649779476645 accuracy is:  0.8980246913580247
# EPOCH 6 On the dev data : mean loss is :  0.5739844532602183  accuracy is :  0.788
# ----------------------------------------------------------------------------
# EPOCH 7 On the training data : mean loss is : 0.22151289280990435 accuracy is:  0.91
# EPOCH 7 On the dev data : mean loss is :  0.6222947084211544  accuracy is :  0.778
# ----------------------------------------------------------------------------
# EPOCH 8 On the training data : mean loss is : 0.20260642130197992 accuracy is:  0.9192592592592592
# EPOCH 8 On the dev data : mean loss is :  0.6159941484014237  accuracy is :  0.785
# ----------------------------------------------------------------------------
# EPOCH 9 On the training data : mean loss is : 0.18824417529403137 accuracy is:  0.9266666666666666
# EPOCH 9 On the dev data : mean loss is :  0.6515359114888672  accuracy is :  0.793
# ----------------------------------------------------------------------------
# EPOCH 10 On the training data : mean loss is : 0.17690085377266482 accuracy is:  0.9320987654320988
# EPOCH 10 On the dev data : mean loss is :  0.7179261535249186  accuracy is :  0.783
# ----------------------------------------------------------------------------
# Duration is  927.8146152999998
# Accuracy on test set for this model is 0.7533333333333333

# %%
durations = [85.89051449999988, 187.4329472000004, 322.5501653000001, 473.0279228999998, 927.8146152999998]
accuracy = [ 0.75, 0.7488888888888889, 0.7588888888888888,0.7522222222222222,0.7533333333333333]
plt.figure(figsize=(5, 3))
plt.title("Accuracy on the test set in terms of embedding dim")
plt.plot(dimensions, accuracy, '*')
plt.ylabel('accuracy')
plt.xlabel('embedding dim')
plt.figure(figsize=(5, 3))
plt.ylabel("time (s)")
plt.xlabel('embedding dim')
plt.title("Training time")
plt.plot(dimensions,durations,'*')

# %% [markdown]
#  ### Network with hidden layers

# %%
class CBOW_classifier_one_hidden_layer(nn.Module):
    def __init__(self, vocab_size , embedding_dim):
        super(CBOW_classifier_one_hidden_layer, self).__init__()
        # To create an embedding table: https://pytorch.org/docs/stable/nn.html#torch.nn.Embedding
        self.embedding = torch.nn.Embedding(num_embeddings = vocab_size ,embedding_dim=embedding_dim)
        
        #1st hidden layer with 50 hidden unit
        self.hidden_1 = torch.nn.Linear(embedding_dim , 2)
        #ouput layer
        self.output = torch.nn.Linear(2,1)
        
        
        #initialisation
        torch.nn.init.xavier_uniform_(self.hidden_1.weight.data)
        torch.nn.init.zeros_(self.hidden_1.bias.data)
        
        torch.nn.init.xavier_uniform_(self.output.weight.data)
        torch.nn.init.zeros_(self.output.bias.data)
        
        
    def forward(self, inputs):
        
        x = self.embedding(inputs)
        x = torch.sum(x, dim=0)
        z = torch.tanh(self.hidden_1(x))

        return(self.output(z))

# %%
loss = nn.BCEWithLogitsLoss()
embedding_dim = 20
hidden_layers_model = CBOW_classifier_one_hidden_layer(len(Dict_train_)+1, embedding_dim)
n_epochs = 10
optimizer = torch.optim.Adam(params=hidden_layers_model.parameters())
train(hidden_layers_model, n_epochs, txt_train, label_train, txt_dev, label_dev, optimizer)
test_accuracy(hidden_layers_model, txt_test , label_test)
# Out:
# EPOCH 1 On the training data : mean loss is : 0.662996789533415 accuracy is:  0.5855555555555556
# EPOCH 1 On the dev data : mean loss is :  0.600331816226244  accuracy is :  0.651
# ----------------------------------------------------------------------------
# EPOCH 2 On the training data : mean loss is : 0.5388606285570581 accuracy is:  0.7208641975308642
# EPOCH 2 On the dev data : mean loss is :  0.5397354798614978  accuracy is :  0.701
# ----------------------------------------------------------------------------
# EPOCH 3 On the training data : mean loss is : 0.45299841265251606 accuracy is:  0.7760493827160494
# EPOCH 3 On the dev data : mean loss is :  0.5218213971629739  accuracy is :  0.721
# ----------------------------------------------------------------------------
# EPOCH 4 On the training data : mean loss is : 0.3912607399861754 accuracy is:  0.8134567901234568
# EPOCH 4 On the dev data : mean loss is :  0.503993304759264  accuracy is :  0.746
# ----------------------------------------------------------------------------
# EPOCH 5 On the training data : mean loss is : 0.34147626652899715 accuracy is:  0.8411111111111111
# EPOCH 5 On the dev data : mean loss is :  0.4998060630597174  accuracy is :  0.757
# ----------------------------------------------------------------------------
# EPOCH 6 On the training data : mean loss is : 0.3036120845703983 accuracy is:  0.8608641975308642
# EPOCH 6 On the dev data : mean loss is :  0.5213373967558146  accuracy is :  0.769
# ----------------------------------------------------------------------------
# EPOCH 7 On the training data : mean loss is : 0.2733360223458321 accuracy is:  0.8758024691358025
# EPOCH 7 On the dev data : mean loss is :  0.5372430905308574  accuracy is :  0.769
# ----------------------------------------------------------------------------
# EPOCH 8 On the training data : mean loss is : 0.24600623110355235 accuracy is:  0.8907407407407407
# EPOCH 8 On the dev data : mean loss is :  0.55192219459638  accuracy is :  0.768
# ----------------------------------------------------------------------------
# EPOCH 9 On the training data : mean loss is : 0.22403734113584145 accuracy is:  0.9007407407407407
# EPOCH 9 On the dev data : mean loss is :  0.5733408684916794  accuracy is :  0.769
# ----------------------------------------------------------------------------
# EPOCH 10 On the training data : mean loss is : 0.20489672194821415 accuracy is:  0.9095061728395062
# EPOCH 10 On the dev data : mean loss is :  0.5837503646221012  accuracy is :  0.768
# ----------------------------------------------------------------------------
# Accuracy on test set for this model is 0.7666666666666667
# 0.7666666666666667

# %%
class CBOW_classifier_two_hidden_layer(nn.Module):
    def __init__(self, vocab_size , embedding_dim):
        super(CBOW_classifier_two_hidden_layer, self).__init__()
        # To create an embedding table: https://pytorch.org/docs/stable/nn.html#torch.nn.Embedding
        self.embedding = torch.nn.Embedding(num_embeddings = vocab_size ,embedding_dim=embedding_dim)
        
        n_hidden = 10
        #1st hidden layer with 50 hidden unit
        self.hidden_1 = torch.nn.Linear(embedding_dim , n_hidden)
        #2end hidden layer with 50 hidden unit   
        self.hidden_2 = torch.nn.Linear(n_hidden , 2)
        
        #ouput layer
        self.output = torch.nn.Linear(2,1)
        
        
        #initialisation
        torch.nn.init.xavier_uniform_(self.hidden_1.weight.data)
        torch.nn.init.zeros_(self.hidden_1.bias.data)

        torch.nn.init.xavier_uniform_(self.hidden_2.weight.data)
        torch.nn.init.zeros_(self.hidden_2.bias.data)
        
        torch.nn.init.xavier_uniform_(self.output.weight.data)
        torch.nn.init.zeros_(self.output.bias.data)
        
        
    def forward(self, inputs):
        
        x = self.embedding(inputs)
        x = torch.sum(x, dim=0)
        z1 = torch.tanh(self.hidden_1(x))
        z2 = torch.tanh(self.hidden_2(z1))
        
        return(self.output(z2))

# %%
loss = nn.BCEWithLogitsLoss()
embedding_dim = 20
hidden_layers_model_2 = CBOW_classifier_two_hidden_layer(len(Dict_train_)+1, embedding_dim)
n_epochs = 10
optimizer = torch.optim.Adam(params=hidden_layers_model_2.parameters())
train(hidden_layers_model_2, n_epochs, txt_train, label_train, txt_dev, label_dev, optimizer)
test_accuracy(hidden_layers_model_2, txt_test , label_test)
# Out:
# EPOCH 1 On the training data : mean loss is : 0.6528488951424758 accuracy is:  0.6079012345679012
# EPOCH 1 On the dev data : mean loss is :  0.6077352452725172  accuracy is :  0.668
# ----------------------------------------------------------------------------
# EPOCH 2 On the training data : mean loss is : 0.5285830978423725 accuracy is:  0.7429629629629629
# EPOCH 2 On the dev data : mean loss is :  0.5530527999699115  accuracy is :  0.71
# ----------------------------------------------------------------------------
# EPOCH 3 On the training data : mean loss is : 0.440548387007029 accuracy is:  0.8061728395061728
# EPOCH 3 On the dev data : mean loss is :  0.5266555563881993  accuracy is :  0.739
# ----------------------------------------------------------------------------
# EPOCH 4 On the training data : mean loss is : 0.3719989005788977 accuracy is:  0.8446913580246913
# EPOCH 4 On the dev data : mean loss is :  0.5364272586964071  accuracy is :  0.746
# ----------------------------------------------------------------------------
# EPOCH 5 On the training data : mean loss is : 0.3143652455782357 accuracy is:  0.8711111111111111
# EPOCH 5 On the dev data : mean loss is :  0.5351412138026208  accuracy is :  0.755
# ----------------------------------------------------------------------------
# EPOCH 6 On the training data : mean loss is : 0.26381366319172544 accuracy is:  0.8965432098765432
# EPOCH 6 On the dev data : mean loss is :  0.5397372593190521  accuracy is :  0.759
# ----------------------------------------------------------------------------
# EPOCH 7 On the training data : mean loss is : 0.21795780398193057 accuracy is:  0.9153086419753086
# EPOCH 7 On the dev data : mean loss is :  0.6024164582090452  accuracy is :  0.752
# ----------------------------------------------------------------------------
# EPOCH 8 On the training data : mean loss is : 0.179316504418643 accuracy is:  0.9277777777777778
# EPOCH 8 On the dev data : mean loss is :  0.6044553954638541  accuracy is :  0.753
# ----------------------------------------------------------------------------
# EPOCH 9 On the training data : mean loss is : 0.147214735448073 accuracy is:  0.9448148148148148
# EPOCH 9 On the dev data : mean loss is :  0.6658469749810174  accuracy is :  0.739
# ----------------------------------------------------------------------------
# EPOCH 10 On the training data : mean loss is : 0.12371437970997283 accuracy is:  0.9538271604938272
# EPOCH 10 On the dev data : mean loss is :  0.7000185047616251  accuracy is :  0.74
# ----------------------------------------------------------------------------
# Accuracy on test set for this model is 0.7444444444444445
# 0.7444444444444445

# %%
class CBOW_classifier_with_one_hidden_layer_and_dropout(nn.Module):
    def __init__(self, vocab_size, embedding_dim, dropout):
        super(CBOW_classifier_with_one_hidden_layer_and_dropout, self).__init__()
        # TODO
        # To create an embedding table: https://pytorch.org/docs/stable/nn.html#torch.nn.Embedding
        self.embedding = torch.nn.Embedding(num_embeddings = vocab_size ,embedding_dim=embedding_dim)
        
        #1st hidden layer with 50 hidden unit
        self.hidden_1 = torch.nn.Linear(embedding_dim , 2)
        #ouput layer
        self.output = torch.nn.Linear(2,1)
        
        self.dropout = nn.Dropout(p=dropout)
        
        #initialisation
        torch.nn.init.xavier_uniform_(self.hidden_1.weight.data)
        torch.nn.init.zeros_(self.hidden_1.bias.data)
        
        torch.nn.init.xavier_uniform_(self.output.weight.data)
        torch.nn.init.zeros_(self.output.bias.data)
        
        
    def forward(self, inputs):
        
        x = self.embedding(inputs)
        x = torch.sum(x, dim=0)
        x = self.dropout(x)
        z = torch.tanh(self.hidden_1(x))

        return(self.output(z))

# %%
dropouts = [0.0, 0.2, 0.5, 0.8]
durations = []
accuracy = []
for dropout in dropouts:
    embedding_dim = 20
    model_d = CBOW_classifier_with_one_hidden_layer_and_dropout(len(Dict_train_), embedding_dim, dropout)
    n_epochs = 10
    # we use Adam with default parameters because the learning rate should be higher for big dropout rates
    optimizer = torch.optim.Adam(params=model_d.parameters())
    start_time = clock()
    train(model_d, n_epochs, txt_train, label_train, txt_dev, label_dev, optimizer)
    durations.append(clock() - start_time)
    accuracy.append(test_accuracy(model_d, txt_test , label_test))
# Out:
# EPOCH 1 On the training data : mean loss is : 0.6583657936770239 accuracy is:  0.5725925925925925
# EPOCH 1 On the dev data : mean loss is :  0.6185248773694039  accuracy is :  0.653
# ----------------------------------------------------------------------------
# EPOCH 2 On the training data : mean loss is : 0.5435320490782644 accuracy is:  0.7167901234567902
# EPOCH 2 On the dev data : mean loss is :  0.5627910759747028  accuracy is :  0.695
# ----------------------------------------------------------------------------
# EPOCH 3 On the training data : mean loss is : 0.4574743795045364 accuracy is:  0.7706172839506172
# EPOCH 3 On the dev data : mean loss is :  0.5378250138163566  accuracy is :  0.723
# ----------------------------------------------------------------------------
# EPOCH 4 On the training data : mean loss is : 0.398858746389548 accuracy is:  0.8053086419753086
# EPOCH 4 On the dev data : mean loss is :  0.5329112893790007  accuracy is :  0.75
# ----------------------------------------------------------------------------
# EPOCH 5 On the training data : mean loss is : 0.35117915202622063 accuracy is:  0.8349382716049383
# EPOCH 5 On the dev data : mean loss is :  0.5371525166928768  accuracy is :  0.746
# ----------------------------------------------------------------------------
# EPOCH 6 On the training data : mean loss is : 0.30849025231360655 accuracy is:  0.8529629629629629
# EPOCH 6 On the dev data : mean loss is :  0.5520909728072584  accuracy is :  0.741
# ----------------------------------------------------------------------------
# EPOCH 7 On the training data : mean loss is : 0.27648509337716265 accuracy is:  0.8667901234567901
# EPOCH 7 On the dev data : mean loss is :  0.5500226875431836  accuracy is :  0.759
# ----------------------------------------------------------------------------
# EPOCH 8 On the training data : mean loss is : 0.24943135453457083 accuracy is:  0.8798765432098765
# EPOCH 8 On the dev data : mean loss is :  0.5630090500637889  accuracy is :  0.766
# ----------------------------------------------------------------------------
# EPOCH 9 On the training data : mean loss is : 0.22819362477249938 accuracy is:  0.8890123456790123
# EPOCH 9 On the dev data : mean loss is :  0.5699136111810803  accuracy is :  0.763
# ----------------------------------------------------------------------------
# EPOCH 10 On the training data : mean loss is : 0.20972882731748677 accuracy is:  0.899753086419753
# EPOCH 10 On the dev data : mean loss is :  0.5977052703248337  accuracy is :  0.761
# ----------------------------------------------------------------------------
# Accuracy on test set for this model is 0.7622222222222222
# EPOCH 1 On the training data : mean loss is : 0.6813970331718893 accuracy is:  0.5561728395061728
# EPOCH 1 On the dev data : mean loss is :  0.6302357940375805  accuracy is :  0.607
# ----------------------------------------------------------------------------
# EPOCH 2 On the training data : mean loss is : 0.5844751780544534 accuracy is:  0.6790123456790124
# EPOCH 2 On the dev data : mean loss is :  0.5823235604763031  accuracy is :  0.687
# ----------------------------------------------------------------------------
# EPOCH 3 On the training data : mean loss is : 0.5229153645185777 accuracy is:  0.7337037037037037
# EPOCH 3 On the dev data : mean loss is :  0.561573680922389  accuracy is :  0.7
# ----------------------------------------------------------------------------
# EPOCH 4 On the training data : mean loss is : 0.47121462018033605 accuracy is:  0.772962962962963
# EPOCH 4 On the dev data : mean loss is :  0.5302225831970573  accuracy is :  0.731
# ----------------------------------------------------------------------------
# EPOCH 5 On the training data : mean loss is : 0.4342832824431452 accuracy is:  0.792716049382716
# EPOCH 5 On the dev data : mean loss is :  0.5213165230005979  accuracy is :  0.726
# ----------------------------------------------------------------------------
# EPOCH 6 On the training data : mean loss is : 0.3969478306266261 accuracy is:  0.8174074074074074
# EPOCH 6 On the dev data : mean loss is :  0.5178106934651733  accuracy is :  0.736
# ----------------------------------------------------------------------------
# EPOCH 7 On the training data : mean loss is : 0.37532233082677846 accuracy is:  0.8307407407407408
# EPOCH 7 On the dev data : mean loss is :  0.5053397981002927  accuracy is :  0.745
# ----------------------------------------------------------------------------
# EPOCH 8 On the training data : mean loss is : 0.35486039702769046 accuracy is:  0.8429629629629629
# EPOCH 8 On the dev data : mean loss is :  0.48633283756673334  accuracy is :  0.765
# ----------------------------------------------------------------------------
# EPOCH 9 On the training data : mean loss is : 0.3334803204689129 accuracy is:  0.8511111111111112
# EPOCH 9 On the dev data : mean loss is :  0.5187146636471153  accuracy is :  0.747
# ----------------------------------------------------------------------------
# EPOCH 10 On the training data : mean loss is : 0.31073389052470896 accuracy is:  0.8627160493827161
# EPOCH 10 On the dev data : mean loss is :  0.49432654843106866  accuracy is :  0.762
# ----------------------------------------------------------------------------
# Accuracy on test set for this model is 0.7544444444444445
# EPOCH 1 On the training data : mean loss is : 0.7062663986653458 accuracy is:  0.5087654320987655
# EPOCH 1 On the dev data : mean loss is :  0.6819506736397744  accuracy is :  0.5
# ----------------------------------------------------------------------------
# EPOCH 2 On the training data : mean loss is : 0.656682296976631 accuracy is:  0.5714814814814815
# EPOCH 2 On the dev data : mean loss is :  0.6503059374690056  accuracy is :  0.623
# ----------------------------------------------------------------------------
# EPOCH 3 On the training data : mean loss is : 0.621518389792354 accuracy is:  0.6530864197530865
# EPOCH 3 On the dev data : mean loss is :  0.6314325965940952  accuracy is :  0.637
# ----------------------------------------------------------------------------
# EPOCH 4 On the training data : mean loss is : 0.5798618481887712 accuracy is:  0.7035802469135802
# EPOCH 4 On the dev data : mean loss is :  0.6019981239140034  accuracy is :  0.668
# ----------------------------------------------------------------------------
# EPOCH 5 On the training data : mean loss is : 0.5495908595879136 accuracy is:  0.7264197530864197
# EPOCH 5 On the dev data : mean loss is :  0.5642545069307089  accuracy is :  0.701
# ----------------------------------------------------------------------------
# EPOCH 6 On the training data : mean loss is : 0.5318574776601644 accuracy is:  0.7459259259259259
# EPOCH 6 On the dev data : mean loss is :  0.5559102198183536  accuracy is :  0.726
# ----------------------------------------------------------------------------
# EPOCH 7 On the training data : mean loss is : 0.5023652566325517 accuracy is:  0.7669135802469136
# EPOCH 7 On the dev data : mean loss is :  0.5493004230856895  accuracy is :  0.72
# ----------------------------------------------------------------------------
# EPOCH 8 On the training data : mean loss is : 0.48820340831154657 accuracy is:  0.7675308641975309
# EPOCH 8 On the dev data : mean loss is :  0.5647200814187526  accuracy is :  0.72
# ----------------------------------------------------------------------------
# EPOCH 9 On the training data : mean loss is : 0.4709507330792186 accuracy is:  0.7820987654320988
# EPOCH 9 On the dev data : mean loss is :  0.5424346257001161  accuracy is :  0.726
# ----------------------------------------------------------------------------
# EPOCH 10 On the training data : mean loss is : 0.4454390539927983 accuracy is:  0.802716049382716
# EPOCH 10 On the dev data : mean loss is :  0.5610331100746989  accuracy is :  0.722
# ----------------------------------------------------------------------------
# Accuracy on test set for this model is 0.7177777777777777
# EPOCH 1 On the training data : mean loss is : 0.7127523142743258 accuracy is:  0.5030864197530864
# EPOCH 1 On the dev data : mean loss is :  0.6918548160791397  accuracy is :  0.5
# ----------------------------------------------------------------------------
# EPOCH 2 On the training data : mean loss is : 0.6896107561352812 accuracy is:  0.5
# EPOCH 2 On the dev data : mean loss is :  0.6849969183206558  accuracy is :  0.5
# ----------------------------------------------------------------------------
# EPOCH 3 On the training data : mean loss is : 0.6833866969633986 accuracy is:  0.5
# EPOCH 3 On the dev data : mean loss is :  0.6784930870831013  accuracy is :  0.5
# ----------------------------------------------------------------------------
# EPOCH 4 On the training data : mean loss is : 0.675531290523064 accuracy is:  0.5330864197530865
# EPOCH 4 On the dev data : mean loss is :  0.6749235306680202  accuracy is :  0.558
# ----------------------------------------------------------------------------
# EPOCH 5 On the training data : mean loss is : 0.6665128516893328 accuracy is:  0.5806172839506173
# EPOCH 5 On the dev data : mean loss is :  0.6655635474324226  accuracy is :  0.572
# ----------------------------------------------------------------------------
# EPOCH 6 On the training data : mean loss is : 0.6547591995162728 accuracy is:  0.6055555555555555
# EPOCH 6 On the dev data : mean loss is :  0.6675406436622143  accuracy is :  0.573
# ----------------------------------------------------------------------------
# EPOCH 7 On the training data : mean loss is : 0.6397685971083464 accuracy is:  0.6255555555555555
# EPOCH 7 On the dev data : mean loss is :  0.6542249649763108  accuracy is :  0.623
# ----------------------------------------------------------------------------
# EPOCH 8 On the training data : mean loss is : 0.6316640400776157 accuracy is:  0.6355555555555555
# EPOCH 8 On the dev data : mean loss is :  0.6249966396093368  accuracy is :  0.656
# ----------------------------------------------------------------------------
# EPOCH 9 On the training data : mean loss is : 0.6217356912442196 accuracy is:  0.6592592592592592
# EPOCH 9 On the dev data : mean loss is :  0.6149154272973537  accuracy is :  0.66
# ----------------------------------------------------------------------------
# EPOCH 10 On the training data : mean loss is : 0.614247606407713 accuracy is:  0.6674074074074074
# EPOCH 10 On the dev data : mean loss is :  0.6156030624210834  accuracy is :  0.655
# ----------------------------------------------------------------------------
# Accuracy on test set for this model is 0.6422222222222222

# %%
plt.figure(figsize=(4, 3))

plt.ylabel("Test accuracy")
plt.xlabel('Dropout rate')
plt.title("Impact of the dropout rate")
plt.plot(dropouts, accuracy,'*')

plt.figure(figsize=(4, 3))

plt.plot()
plt.ylabel("Training time")
plt.xlabel('Dropout rate')
plt.title("Impact of the dropout rate")
plt.plot(dropouts, durations,'*')
# Out:
# [0.7622222222222222, 0.7544444444444445, 0.7177777777777777, 0.6422222222222222]

# %%
class CBOW_classifier_two_hidden_layer_and_dropout(nn.Module):
    def __init__(self, vocab_size , embedding_dim, dropout):
        super(CBOW_classifier_two_hidden_layer_and_dropout, self).__init__()
        # To create an embedding table: https://pytorch.org/docs/stable/nn.html#torch.nn.Embedding
        self.embedding = torch.nn.Embedding(num_embeddings = vocab_size ,embedding_dim=embedding_dim)
        
        n_hidden = 10
        #1st hidden layer with 50 hidden unit
        self.hidden_1 = torch.nn.Linear(embedding_dim , n_hidden)
        #2end hidden layer with 50 hidden unit   
        self.hidden_2 = torch.nn.Linear(n_hidden , 2)
        
        #ouput layer
        self.output = torch.nn.Linear(2,1)
        
        # dropouting function
        self.dropout = nn.Dropout(p=dropout)
        
        #initialisation
        torch.nn.init.xavier_uniform_(self.hidden_1.weight.data)
        torch.nn.init.zeros_(self.hidden_1.bias.data)

        torch.nn.init.xavier_uniform_(self.hidden_2.weight.data)
        torch.nn.init.zeros_(self.hidden_2.bias.data)
        
        torch.nn.init.xavier_uniform_(self.output.weight.data)
        torch.nn.init.zeros_(self.output.bias.data)
        
        
    def forward(self, inputs):
        
        x = self.embedding(inputs)
        x = torch.sum(x, dim=0)
        z1 = self.dropout(torch.tanh(self.hidden_1(x)))
        z2 = self.dropout(torch.tanh(self.hidden_2(z1)))
        
        return(self.output(z2))

# %%
dropouts = [0.0, 0.2, 0.5, 0.8]
durations = []
accuracy = []
embedding_dim = 20
for dropout in dropouts:
    model_d = CBOW_classifier_two_hidden_layer_and_dropout(len(Dict_train_), embedding_dim, dropout)
    n_epochs = 10
    # we use Adam with default parameters because the learning rate should be higher for big dropout rates
    optimizer = torch.optim.Adam(params=model_d.parameters())
    start_time = clock()
    train(model_d, n_epochs, txt_train, label_train, txt_dev, label_dev, optimizer)
    durations.append(clock() - start_time)
    accuracy.append(test_accuracy(model_d, txt_test , label_test))
# Out:
# EPOCH 1 On the training data : mean loss is : 0.6646782116757499 accuracy is:  0.5750617283950618
# EPOCH 1 On the dev data : mean loss is :  0.6043232718259096  accuracy is :  0.671
# ----------------------------------------------------------------------------
# EPOCH 2 On the training data : mean loss is : 0.5354990092848922 accuracy is:  0.7274074074074074
# EPOCH 2 On the dev data : mean loss is :  0.5423061060905456  accuracy is :  0.72
# ----------------------------------------------------------------------------
# EPOCH 3 On the training data : mean loss is : 0.43440872889242055 accuracy is:  0.7987654320987654
# EPOCH 3 On the dev data : mean loss is :  0.5263670535422862  accuracy is :  0.749
# ----------------------------------------------------------------------------
# EPOCH 4 On the training data : mean loss is : 0.3519022534346139 accuracy is:  0.8453086419753086
# EPOCH 4 On the dev data : mean loss is :  0.5283636422529817  accuracy is :  0.751
# ----------------------------------------------------------------------------
# EPOCH 5 On the training data : mean loss is : 0.28740674648801856 accuracy is:  0.8808641975308642
# EPOCH 5 On the dev data : mean loss is :  0.5426918907817453  accuracy is :  0.763
# ----------------------------------------------------------------------------
# EPOCH 6 On the training data : mean loss is : 0.23334275241412314 accuracy is:  0.9088888888888889
# EPOCH 6 On the dev data : mean loss is :  0.5940252245683223  accuracy is :  0.759
# ----------------------------------------------------------------------------
# EPOCH 7 On the training data : mean loss is : 0.19199022857000891 accuracy is:  0.927037037037037
# EPOCH 7 On the dev data : mean loss is :  0.6122575563741848  accuracy is :  0.749
# ----------------------------------------------------------------------------
# EPOCH 8 On the training data : mean loss is : 0.1587486890685043 accuracy is:  0.9432098765432099
# EPOCH 8 On the dev data : mean loss is :  0.622093626530841  accuracy is :  0.76
# ----------------------------------------------------------------------------
# EPOCH 9 On the training data : mean loss is : 0.13198309433261324 accuracy is:  0.9548148148148148
# EPOCH 9 On the dev data : mean loss is :  0.6773639685637317  accuracy is :  0.753
# ----------------------------------------------------------------------------
# EPOCH 10 On the training data : mean loss is : 0.10807181976839073 accuracy is:  0.9617283950617284
# EPOCH 10 On the dev data : mean loss is :  0.7391704412584659  accuracy is :  0.742
# ----------------------------------------------------------------------------
# Accuracy on test set for this model is 0.74
# EPOCH 1 On the training data : mean loss is : 0.6742868125475483 accuracy is:  0.5374074074074074
# EPOCH 1 On the dev data : mean loss is :  0.6467052137553692  accuracy is :  0.594
# ----------------------------------------------------------------------------
# EPOCH 2 On the training data : mean loss is : 0.5843553363633008 accuracy is:  0.6832098765432099
# EPOCH 2 On the dev data : mean loss is :  0.5882828007042408  accuracy is :  0.699
# ----------------------------------------------------------------------------
# EPOCH 3 On the training data : mean loss is : 0.5138828403300342 accuracy is:  0.755432098765432
# EPOCH 3 On the dev data : mean loss is :  0.5474953661710024  accuracy is :  0.724
# ----------------------------------------------------------------------------
# EPOCH 4 On the training data : mean loss is : 0.45534568573129763 accuracy is:  0.7948148148148149
# EPOCH 4 On the dev data : mean loss is :  0.544014184910804  accuracy is :  0.738
# ----------------------------------------------------------------------------
# EPOCH 5 On the training data : mean loss is : 0.4181484378791518 accuracy is:  0.8171604938271605
# EPOCH 5 On the dev data : mean loss is :  0.5637143834084273  accuracy is :  0.752
# ----------------------------------------------------------------------------
# EPOCH 6 On the training data : mean loss is : 0.3748154383143525 accuracy is:  0.8440740740740741
# EPOCH 6 On the dev data : mean loss is :  0.5473906872887164  accuracy is :  0.766
# ----------------------------------------------------------------------------
# EPOCH 7 On the training data : mean loss is : 0.33988279123871046 accuracy is:  0.8577777777777778
# EPOCH 7 On the dev data : mean loss is :  0.5793000704199076  accuracy is :  0.761
# ----------------------------------------------------------------------------
# EPOCH 8 On the training data : mean loss is : 0.3129726980075838 accuracy is:  0.8709876543209877
# EPOCH 8 On the dev data : mean loss is :  0.5698790046051144  accuracy is :  0.762
# ----------------------------------------------------------------------------
# EPOCH 9 On the training data : mean loss is : 0.2850532541410239 accuracy is:  0.8866666666666667
# EPOCH 9 On the dev data : mean loss is :  0.5932606955347582  accuracy is :  0.755
# ----------------------------------------------------------------------------
# EPOCH 10 On the training data : mean loss is : 0.2656882298456068 accuracy is:  0.8961728395061729
# EPOCH 10 On the dev data : mean loss is :  0.6058338812682778  accuracy is :  0.764
# ----------------------------------------------------------------------------
# Accuracy on test set for this model is 0.7488888888888889
# EPOCH 1 On the training data : mean loss is : 0.7282120534616672 accuracy is:  0.5234567901234568
# EPOCH 1 On the dev data : mean loss is :  0.6866518791913986  accuracy is :  0.535
# ----------------------------------------------------------------------------
# EPOCH 2 On the training data : mean loss is : 0.6564415853737313 accuracy is:  0.575925925925926
# EPOCH 2 On the dev data : mean loss is :  0.6451764545738697  accuracy is :  0.567
# ----------------------------------------------------------------------------
# EPOCH 3 On the training data : mean loss is : 0.6180089872707555 accuracy is:  0.6496296296296297
# EPOCH 3 On the dev data : mean loss is :  0.6150649873614311  accuracy is :  0.666
# ----------------------------------------------------------------------------
# EPOCH 4 On the training data : mean loss is : 0.5792071558617883 accuracy is:  0.6871604938271605
# EPOCH 4 On the dev data : mean loss is :  0.6056998899802566  accuracy is :  0.672
# ----------------------------------------------------------------------------
# EPOCH 5 On the training data : mean loss is : 0.5467662770834602 accuracy is:  0.7158024691358025
# EPOCH 5 On the dev data : mean loss is :  0.6036784722208977  accuracy is :  0.674
# ----------------------------------------------------------------------------
# EPOCH 6 On the training data : mean loss is : 0.5197741791932488 accuracy is:  0.7346913580246913
# EPOCH 6 On the dev data : mean loss is :  0.6253237892612815  accuracy is :  0.681
# ----------------------------------------------------------------------------
# EPOCH 7 On the training data : mean loss is : 0.4916103727280818 accuracy is:  0.748641975308642
# EPOCH 7 On the dev data : mean loss is :  0.5886054472327232  accuracy is :  0.695
# ----------------------------------------------------------------------------
# EPOCH 8 On the training data : mean loss is : 0.4713320334692612 accuracy is:  0.7670370370370371
# EPOCH 8 On the dev data : mean loss is :  0.5905267010740936  accuracy is :  0.692
# ----------------------------------------------------------------------------
# EPOCH 9 On the training data : mean loss is : 0.4628736535889775 accuracy is:  0.7658024691358025
# EPOCH 9 On the dev data : mean loss is :  0.5903402749672532  accuracy is :  0.702
# ----------------------------------------------------------------------------
# EPOCH 10 On the training data : mean loss is : 0.45104865924512716 accuracy is:  0.7724691358024691
# EPOCH 10 On the dev data : mean loss is :  0.6038853871412575  accuracy is :  0.699
# ----------------------------------------------------------------------------
# Accuracy on test set for this model is 0.6911111111111111
# EPOCH 1 On the training data : mean loss is : 0.7562669341547277 accuracy is:  0.5030864197530864
# EPOCH 1 On the dev data : mean loss is :  0.6926526492834091  accuracy is :  0.5
# ----------------------------------------------------------------------------
# EPOCH 2 On the training data : mean loss is : 0.6929940016365346 accuracy is:  0.49950617283950616
# EPOCH 2 On the dev data : mean loss is :  0.690566408932209  accuracy is :  0.503
# ----------------------------------------------------------------------------
# EPOCH 3 On the training data : mean loss is : 0.6910706863579926 accuracy is:  0.501358024691358
# EPOCH 3 On the dev data : mean loss is :  0.681705872297287  accuracy is :  0.514
# ----------------------------------------------------------------------------
# EPOCH 4 On the training data : mean loss is : 0.6879137970194404 accuracy is:  0.5106172839506172
# EPOCH 4 On the dev data : mean loss is :  0.6803304164707661  accuracy is :  0.517
# ----------------------------------------------------------------------------
# EPOCH 5 On the training data : mean loss is : 0.6813230436341262 accuracy is:  0.5260493827160494
# EPOCH 5 On the dev data : mean loss is :  0.67039732606709  accuracy is :  0.557
# ----------------------------------------------------------------------------
# EPOCH 6 On the training data : mean loss is : 0.6747351684743239 accuracy is:  0.5461728395061728
# EPOCH 6 On the dev data : mean loss is :  0.6723064651340246  accuracy is :  0.562
# ----------------------------------------------------------------------------
# EPOCH 7 On the training data : mean loss is : 0.6632820394359253 accuracy is:  0.564320987654321
# EPOCH 7 On the dev data : mean loss is :  0.6724388941079378  accuracy is :  0.551
# ----------------------------------------------------------------------------
# EPOCH 8 On the training data : mean loss is : 0.6602151115155882 accuracy is:  0.5646913580246914
# EPOCH 8 On the dev data : mean loss is :  0.6728141670301556  accuracy is :  0.559
# ----------------------------------------------------------------------------
# EPOCH 9 On the training data : mean loss is : 0.6522693310678005 accuracy is:  0.572716049382716
# EPOCH 9 On the dev data : mean loss is :  0.660436549142003  accuracy is :  0.581
# ----------------------------------------------------------------------------
# EPOCH 10 On the training data : mean loss is : 0.6499319792888415 accuracy is:  0.5782716049382716
# EPOCH 10 On the dev data : mean loss is :  0.6590654596239328  accuracy is :  0.577
# ----------------------------------------------------------------------------
# Accuracy on test set for this model is 0.5622222222222222

# %%
plt.figure(figsize=(4, 3))

plt.ylabel("Test accuracy")
plt.xlabel('Dropout rate')
plt.title("Impact of the dropout rate")
plt.plot(dropouts, accuracy,'*')

plt.figure(figsize=(4, 3))

plt.plot()
plt.ylabel("Training time")
plt.xlabel('Dropout rate')
plt.title("Impact of the dropout rate")
plt.plot(dropouts, durations,'*')

# %%
class CBOW_classifier_four_hidden_layer(nn.Module):
    def __init__(self, vocab_size , embedding_dim=100):
        super(CBOW_classifier_four_hidden_layer, self).__init__()
        # To create an embedding table: https://pytorch.org/docs/stable/nn.html#torch.nn.Embedding
        self.embedding = torch.nn.Embedding(num_embeddings = vocab_size ,embedding_dim=embedding_dim)
        
        #1st hidden layer with 50 hidden units
        self.hidden_1 = torch.nn.Linear(embedding_dim , 50)
        #2nd hidden layer with 40 hidden units
        self.hidden_2 = torch.nn.Linear(50 , 40)
        #3nd hidden layer with 30 hidden units
        self.hidden_3 = torch.nn.Linear(40 , 30)
        #4nd hidden layer with 30 hidden units
        self.hidden_4 = torch.nn.Linear(30 , 2)
        
        #ouput layer
        self.output = torch.nn.Linear(2,1)
        
        
        #initialisation
        torch.nn.init.xavier_uniform_(self.hidden_1.weight.data)
        torch.nn.init.zeros_(self.hidden_1.bias.data)
        
        torch.nn.init.xavier_uniform_(self.hidden_2.weight.data)
        torch.nn.init.zeros_(self.hidden_2.bias.data)
        
        torch.nn.init.xavier_uniform_(self.hidden_3.weight.data)
        torch.nn.init.zeros_(self.hidden_3.bias.data)
        
        torch.nn.init.xavier_uniform_(self.hidden_4.weight.data)
        torch.nn.init.zeros_(self.hidden_4.bias.data)
        
        torch.nn.init.xavier_uniform_(self.output.weight.data)
        torch.nn.init.zeros_(self.output.bias.data)
        
        
    def forward(self, inputs):
        
        x = self.embedding(inputs).sum(dim=0)
        z1 = torch.tanh(self.hidden_1(x))
        z2 = torch.tanh(self.hidden_2(z1))
        z3 = torch.tanh(self.hidden_3(z2))
        z4 = torch.tanh(self.hidden_4(z3))
        
        output = self.output(z4)
        
        return(output)

# %%
loss = nn.BCEWithLogitsLoss()
embedding_dim = 20
four_hidden_layers_model = CBOW_classifier_four_hidden_layer(len(Dict_train_)+1, embedding_dim)
n_epochs = 10
optimizer = torch.optim.Adam(params=four_hidden_layers_model.parameters())
train(four_hidden_layers_model, n_epochs, txt_train, label_train, txt_dev, label_dev, optimizer)
test_accuracy(four_hidden_layers_model, txt_test , label_test)
# Out:
# EPOCH 1 On the training data : mean loss is : 0.6409385825196902 accuracy is:  0.6293827160493827
# EPOCH 1 On the dev data : mean loss is :  0.579976378172636  accuracy is :  0.701
# ----------------------------------------------------------------------------
# EPOCH 2 On the training data : mean loss is : 0.5282917432818148 accuracy is:  0.7407407407407407
# EPOCH 2 On the dev data : mean loss is :  0.5288118252754211  accuracy is :  0.734
# ----------------------------------------------------------------------------
# EPOCH 3 On the training data : mean loss is : 0.4483909151335189 accuracy is:  0.7997530864197531
# EPOCH 3 On the dev data : mean loss is :  0.49303907762467863  accuracy is :  0.767
# ----------------------------------------------------------------------------
# EPOCH 4 On the training data : mean loss is : 0.38304428375705524 accuracy is:  0.8381481481481482
# EPOCH 4 On the dev data : mean loss is :  0.5040033432990313  accuracy is :  0.777
# ----------------------------------------------------------------------------
# EPOCH 5 On the training data : mean loss is : 0.33496732109444743 accuracy is:  0.8597530864197531
# EPOCH 5 On the dev data : mean loss is :  0.5297920576184988  accuracy is :  0.776
# ----------------------------------------------------------------------------
# EPOCH 6 On the training data : mean loss is : 0.2930726246361011 accuracy is:  0.8865432098765432
# EPOCH 6 On the dev data : mean loss is :  0.5178455134704709  accuracy is :  0.776
# ----------------------------------------------------------------------------
# EPOCH 7 On the training data : mean loss is : 0.2533222236091064 accuracy is:  0.904320987654321
# EPOCH 7 On the dev data : mean loss is :  0.5521799005493522  accuracy is :  0.78
# ----------------------------------------------------------------------------
# EPOCH 8 On the training data : mean loss is : 0.2174545963957078 accuracy is:  0.9218518518518518
# EPOCH 8 On the dev data : mean loss is :  0.6028769706059247  accuracy is :  0.771
# ----------------------------------------------------------------------------
# EPOCH 9 On the training data : mean loss is : 0.1848499239806408 accuracy is:  0.9360493827160494
# EPOCH 9 On the dev data : mean loss is :  0.626775896154344  accuracy is :  0.771
# ----------------------------------------------------------------------------
# EPOCH 10 On the training data : mean loss is : 0.1554779969194881 accuracy is:  0.9498765432098766
# EPOCH 10 On the dev data : mean loss is :  0.6728192599490285  accuracy is :  0.763
# ----------------------------------------------------------------------------
# Accuracy on test set for this model is 0.7411111111111112
# 0.7411111111111112
